# %% [markdown]
# # Comando INSERT
# ## Ejemplo
# insert into NOMBRETABLA (CAMPO1, CAMPO2, ..., CAMPOn) values(deben ser los mismos tipos que los campos)
# En los campos debes poner si o si las claves primarias y foraneas y columnas que esten mandatorias
# insert into employees (employee_id, first_name, last_name, email, phone_number, hire_date, job_id, salary, department_id)
# values ('301', 'Carlos', 'Ramirez', 'CRAMIREZ', '555-1234', to_date('2023-06-01','YYYY-MM-DD'), 19, 6000, 6)
#
# ## RETO DE ANA TORRES
# ### Tuyo
# insert into employees (employee_id, first_name, last_name, email, phone_number, hire_date, job_id, salary, department_id)
# values ('303', 'Ana', 'Torres', 'ANAT', '555-1234', to_date('2023-06-01','YYYY-MM-DD'),
# (select job_id from employees where employee_id = 101),
# (select salary from employees where employee_id = 101),
# (select department_id from employees where employee_id = 101)
# )
#
# ### Del Inge
# insert into employees (employee_id, first_name, last_name, email, phone_number, hire_date, job_id, salary, department_id)
# select 301, 'Ana', 'Torres', 'ATORRES', '555-9000', SYSDATE,
# job_id, salary, department_id from employees where employee_id = 101

# %%
! pip install oracledb
import oracledb
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
conn = oracledb.connect(
    user="HR",
    password="basededatos",
    dsn="localhost:1521/XE"
)

cursor = conn.cursor()

# %%
#cursor.execute(
"""
insert into employees (employee_id, first_name, last_name, email, phone_number, hire_date, job_id, salary, department_id)
values ('301', 'Carlos', 'Ramirez', 'CRAMIREZ', '555-1234', to_date('2023-06-01','YYYY-MM-DD'), 19, 6000, 6)    
"""
#)

cursor.execute("select * from employees where employee_id = '301'")
for row in cursor.fetchall():
    print(row)

# %% [markdown]
# # Actualizacion
# update employees
# set salary = 6500
# where employee_id = 300
#
# update employees
# set salary = salary + 10
# where department_id = 3
#
# update employees
# set salary = salary*1.1
# where salary<(select avg(salary) from employees)

# %% [markdown]
# # Eliminar
# delete from employees
# where employee_id = 300
#
# delete from employees
# where department_id in (
#     select department_id from departments d
#     join locations l on d.location_id=l.location_id
#     join countries c on l.country_id = c.country_id
#     join regions r on c.region_id = r.region_id
#     where r.region_name = 'Europe'
# )
